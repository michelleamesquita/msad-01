# %% [markdown]
# # MSAD 2026.1 — Primeiro Trabalho
#
# Notebook de análise: Bellcore + Silence of the Lambs.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'scripts'))
from analise_trabalho import analyze_bellcore, analyze_movie, FIG, RESULTS
import json

# %% [markdown]
# ## 1. Bellcore

# %%
bellcore = analyze_bellcore()

# %%
import json
print(json.dumps(bellcore['tarefas']['a_original'], indent=2))

# %% [markdown]
# ### Figuras Bellcore

# %%
from IPython.display import Image, display
for name in ['bellcore_original_hist_cdf', 'bellcore_ccdf_comparativo', 'bellcore_acf_comparativo']:
    display(Image(filename=str(FIG / f'{name}.png')))

# %% [markdown]
# ## 2. Silence of the Lambs

# %%
movie = analyze_movie()

# %%
import pandas as pd
pd.DataFrame(movie['tarefas']['a_estatisticas']).T

# %% [markdown]
# ### Figuras Movie

# %%
for name in ['movie_ALL_hist_cdf', 'movie_ccdf_comparativo', 'movie_acf_comparativo']:
    display(Image(filename=str(FIG / f'{name}.png')))

# %%
with open(RESULTS / 'metricas.json', 'w') as f:
    json.dump({'bellcore': bellcore, 'movie': movie}, f, indent=2)
print('Métricas atualizadas.')
